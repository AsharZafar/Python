# %% [markdown]
# <a href="https://colab.research.google.com/github/AsharZafar/Python/blob/main/DataScienceEcosystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Science Tools and Ecosystem

# %% [markdown]
# #In this notebook, Data Science Tools and Ecosystem are summarized.

# %%
#In this notebook, Data Science Tools and Ecosystem are summarized.

Python
Jupyter notebook
R
Machine learning

# %% [markdown]
# Some of the popular languages that Data Scientists use are:

# %%
Python
R
Pandas
Java
Machine learning

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:

# %%
Numpy
Pandas
Sikit learn
Machine learning

# %% [markdown]
# Data Science Tools

# %%
Pandas
Python
Deep learning
R

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python

# %%
result = 5 + 3
print("Addition:", result)

# Subtraction
result = 10 - 4
print("Subtraction:", result)

# Multiplication
result = 6 * 7
print("Multiplication:", result)

# Division
result = 20 / 5
print("Division:", result)

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60.

# %%
# Input: number of minutes
minutes = 120

# Conversion to hours
hours = minutes / 60

# Output
print(f"{minutes} minutes is equal to {hours} hours.")

# %% [markdown]
# Objectives:

# %% [markdown]
# popular languages for Data Science
# Python
# R
# Java
# Popular tools
# Java
# Machine learning
# Deep learning
# Keras
